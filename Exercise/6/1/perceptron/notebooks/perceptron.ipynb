# %% [markdown]
# <h1 align=center style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پرسپترون
# </font>
# </h1>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مقدمه و صورت مسئله
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     به یک تمرین اساسی از پایه‌ای‌ترین مباحث شبکه‌های عصبی خوش آمدید! در این تمرین رویکرد متفاوتی را در پیش خواهیم گرفت و قصد داریم ساختار پرسپترون و الگوریتم آموزش آن را که در درسنامه‌های پیشین آموختید مستقیماً پیاده‌سازی کنیم. کدنویسی در این سطح به شما کمک خواهد کرد که به شکل عملی درک عمیق‌تری از نحوه‌ی کار این مدل پیدا کنید و در آینده نیز هنگام مواجه با مدل‌های مختلف شبکه‌های عصبی قادر به تحلیل آسان‌تر ساختار آن‌ها باشید. پس از طراحی پرسپترون، آن را روی مجموعه‌داده‌ی مشهور <i>گل‌های زنبق (iris)</i> آموزش داده و عملکرد دو روش مختلف آموزش پرسپترون، یعنی قاعده‌ی پرسپترون و قاعده‌ی دلتا را بر روی این مجموعه‌داده ارزیابی خواهیم کرد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# وارد کردن کتابخانه‌های مورد نیاز
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     ابتدا کتابخانه‌های مورد نیازتان را وارد کنید.
# </font>
# </p>

# %%
import json
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score
from inspect import getsource

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# معرفی مجموعه‌داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در این تمرین از مجموعه‌‌داده‌ی ساده اما مشهور گل‌های زنبق (iris) استفاده خواهیم کرد. این مجموعه‌داده شامل سه دسته (نوع گیاه) است که از هر دسته 50 نمونه داده وجود دارد. هر داده دارای یک برچسب و چهار ویژگی است که در جدول زیر معرفی شده‌اند.
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ستون|توضیحات|
# |:------:|:---:|
# |SepalLengthCm|طول کاسبرگ (سانتی‌متر)|
# |SepalWidthCm|عرض کاسبرگ (سانتی‌متر)|
# |PetalLengthCm|طول گلبرگ (سانتی‌متر)|
# |PetalWidthCm|عرض گلبرگ (سانتی‌متر)|
# |Species|نوع گیاه (متغیر هدف)|
#
# </font>
# </div>
# </center>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# خواندن مجموعه داده
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     در ابتدا نیاز است فایل‌ مجموعه‌داده را بخوانید. برای این تمرین مجموعه‌ی آزمونی در نظر گرفته نشده و هدف تنها پیاده‌سازی و تحلیل مدل است. بنابراین کل مجموعه‌داده را می‌توانید از فایل <code>iris.csv</code> موجود در پوشه‌ی مسئله خوانده و از نمونه‌های موجود در آن برای آموزش پرسپترون استفاده کنید. توجه داشته باشید که نیازی به ستون <code>Id</code> ندارید و می‌توانید آن را از دیتافریم خود حذف کنید.
# </font>
# </p>

# %%
train_data = pd.read_csv('../data/iris.csv')
train_data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
train_data['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# پیش‌پردازش و مهندسی ویژگی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     اگر به مقادیر ستون <code>Species</code> نگاه کرده باشید، دریافته‌اید که این مجموعه‌داده دارای سه کلاس <code>Iris-setosa</code> ،<code>Iris-versicolor</code> و <code>Iris-virginica</code> است.
#     <br>
#     از آنجا که یک پرسپترون واحد قادر به دسته‌بندی دوکلاسه هست در این تمرین قصد داریم سه مدل مختلف را آموزش دهیم که هرکدام از آن‌ها بین یک ترکیب دوتایی از سه دسته ممکن تصمیم‌گیری می‌کند. یعنی قرار است تا سه پرسپترون را به شکل زیر آموزش دهیم:
# </font>
# </p>
# <ul dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     <li>تصمیم‌گیری بین دو دسته‌ی <code>Iris-setosa</code> و <code>Iris-versicolor</code></li>
#     <li>تصمیم‌گیری بین دو دسته‌ی <code>Iris-setosa</code> و <code>Iris-virginica</code></li>
#     <li>تصمیم‌گیری بین دو دسته‌ی <code>Iris-versicolor</code> و <code>Iris-virginica</code></li>
# </font>
# </ul>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     این امر همچنین به ما کمک می‌کند تا به‌صورت تجربی کشف کنیم که کدام دسته از سایر دسته‌ها به‌صورت خطی تفکیک‌پذیر است.
# </font>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     بنابراین از شما خواسته می‌شود که دیتافریم اصلی را به سه دیتافریم کوچک‌تر (با نام‌های <code>df2</code> ،<code>df1</code> و <code>df3</code>) تقسیم کنید، به شکلی که در هر دیتافریم تنها نمونه‌های مربوط به یکی از حالت‌های لیست بالا وجود داشته باشد. به عنوان مثال در دیتافریم نخست یعنی <code>df1</code> تنها نمونه‌های حالت اول یعنی دسته‌های <code>Iris-setosa</code> و <code>Iris-versicolor</code> وجود داشته باشد.
# </font>

# %%
train_data.drop(columns= 'Id', inplace= True)

df1 = train_data[(train_data['Species'] == 'Iris-setosa') | (train_data['Species'] == 'Iris-versicolor')]

df2 = train_data[(train_data['Species'] == 'Iris-setosa') | (train_data['Species'] == 'Iris-virginica')]

df3 = train_data[(train_data['Species'] == 'Iris-virginica') | (train_data['Species'] == 'Iris-versicolor')]

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# کد زیر دیتافریم‌های شما را ذخیره می‌کند تا در انتهای نت‌بوک به فایل جواب شما اضافه شود. سه دیتافریم بالا از نظر تعداد نمونه، ستون‌ها و مقادیر موجود در ستون <code>Species</code> داوری خواهند شد. نیازی به تغییر کد نیست و کافیست تنها سلول را اجرا نمایید.
# </font>

# %%
df1.to_csv('df1.csv', index=False)
df2.to_csv('df2.csv', index=False)
df3.to_csv('df3.csv', index=False)

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     اکنون اگر قصد دارید می‌توانید پیش‌پردازش‌های دلخواه خود را بر روی مقادیر ویژگی‌ها انجام دهید. همچنین توجه داشته باشید مقادیر ستون برچسب را باید به شکل اعداد <code dir=ltr>+1</code> و <code dir=ltr>-1</code> کدگذاری کنید. علاوه بر این فراموش نکنید که ستون‌های ویژگی را از ستون متغیر هدف (برچسب) جدا کنید.
# </font>

# %%
target_df1 = df1['Species']
target_df2 = df2['Species']
target_df3 = df3['Species']

df1.drop(columns= 'Species', inplace= True)
df2.drop(columns= 'Species', inplace= True)
df3.drop(columns= 'Species', inplace= True)

target_df1 = target_df1.map({'Iris-setosa': -1, 'Iris-versicolor': 1})
target_df2 = target_df2.map({'Iris-setosa': -1, 'Iris-virginica': 1})
target_df3 = target_df3.map({'Iris-versicolor': -1, 'Iris-virginica': 1})

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df1 = scaler.fit_transform(df1)
df2 = scaler.fit_transform(df2)
df3 = scaler.fit_transform(df3)
# Out:
# c:\Users\user\Desktop\python\machine learning\qenv\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# مدل‌سازی
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     اکنون که داده‌ها را پردازش و آماده کردید نوبت به قسمت اصلی یعنی مدل می‌رسد. همانطور که در ابتدا ذکر کردیم در این تمرین دیگر خبری از کتابخانه‌ی آماده‌ی <code>scikit-learn</code> نیست. در اینجا از شما خواسته شده تا یک مدل ساده‌ی پرسپترون را به دو حالت (قاعده‌ی پرسپترون و قاعده‌ی دلتا) از صفر پیاده کنید. برای این کار قدم به قدم هر جزء این مدل را شرح خواهیم داد تا نسبت به پیاده‌‌سازی آن اقدام کنید.
#     <br>
#     <b>نکته: </b>
#     در اعمال ریاضی و محاسباتی خود تنها از کتابخانه‌ی نامپای استفاده کنید و لیست‌های خود را نیز به شکل آرایه‌ی نامپای تعریف کنید.
#     <br>
# </font>
# </p>

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قاعده‌ی پرسپترون
# </font>
# </h3>
# <center>
#     <img src="perceptron_rule.png">
# <center>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir">
#     به منظور پیاده‌سازی مدل،‌ کلاسی با نام <code>Perceptron</code> تعریف خواهیم کرد که در هنگام ساخته شدن (<code>__init__</code>) یک ویژگی مرتبط با وزن‌ها را با نام <code>weights</code> به این کلاس اضافه می‌کند. بنابراین در هنگام پیاده‌سازی توابع جهت دسترسی به وزن‌های پرسپترون می‌توانید از <code>self.weights</code> استفاده کنید.
#     <br>
#     اکنون هرکدام از توابع مورد نیاز این کلاس را شرح خواهیم داد تا شما به پیاده‌سازی آن‌ها بپردازید:
#     <br>
#     <ul dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <li>
#         تابع <code>weighting</code> مقادیر ویژگی‌های یک نمونه را گرفته و آن را در بردار وزن ضرب نقطه‌ای می‌کند. سپس ورودی وزن‌دار شده به عنوان خروجی برگردانده می‌شود.
#         </li>
#         <li>
#         در تابعی به نام <code>activation</code> تابع فعال‌ساز را که در اینجا تابع علامت است پیاده خواهیم کرد. این تابع، ورودی وزن‌دار را گرفته و در صورتیکه حاصل بیشتر یا مساوی صفر بود خروجی <code>1</code> و در غیر این‌صورت خروجی <code dir=ltr>-1</code> تولید می‌کند.
#         </li>
#         <li>
#         تابع <code>predict</code> آرایه‌ای از نمونه‌ها را گرفته و آرایه‌ای شامل برچسب پیش‌بینی‌شده برای هرکدام از نمونه‌ها را بر می‌گرداند. در این تابع باید به ازای هر نمونه ابتدا آن را به کمک تابع <code>weighting</code> وزن دار کنید و حاصل را به تابع <code>activation</code> بدهید تا برچسب <code dir=ltr>+1</code> یا <code dir=ltr>-1</code> را برای نمونه تولید کند.
#         </li>
#         <li>
#         الگوریتم اصلی پرسپترون در واقع در تابع <code>fit</code> پیاده می‌شود. این تابع ورودی‌ها و هایپرپارامترهای زیر را گرفته و سپس طبق مراحلی که شرح خواهیم داد شروع به آموزش [وزن‌های] پرسپترون می‌کند.
#         </li>
#     </ul>
# </font>
# </p>
#
# <center>
# <div dir=rtl style="direction: rtl;line-height:200%;font-family:vazir;font-size:medium">
# <font face="vazir" size=3>
#
# |ورودی|توضیحات|
# |:------:|:---:|
# |inputs|ویژگی‌های ورودی نمونه‌های آموزشی|
# |outputs|متغیر هدف (برچسب) نمونه‌‌های آموزشی|
# |learning_rate|نرخ یادگیری (η)|
# |epochs|تعداد دفعات آموزش بر روی تمام نمونه‌ها|
#
# </font>
# </div>
# </center>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium; padding-right:40px;">
# <font face="vazir">
# در درسنامه‌ی پرسپترون اشاره کردیم که عبارت بایاس را می‌توان به کمک اضافه کردن یک ورودی ثابت <code>1</code> به ویژگی‌های ورودی تعبیه کرد. بنابراین در تابع <code>fit</code> ابتدا به اول ویژگی‌های هرکدام از نمونه‌ها عدد <code>1</code> را اضافه کنید (به عنوان مثال برای نمونه‌ی <code>inputs[i]</code>، باید <code>inputs[i][0]</code> برابر <code>1</code> باشد). با این کار یک واحد به طول بردار ویژگی نمونه‌ها اضافه خواهد شد. (فراموش نکنید که این کار را در هنگام پیش‌بینی یعنی تابع predict نیز باید انجام دهید.)
# <br>
# پس از آن نیاز است تا بردار وزن یعنی <code>self.weights</code> را ساخته و مقداردهی کنید. برای مقداردهی اولیه می‌توانید از اعداد تصادفی بین <code dir=ltr>0</code> تا <code dir=ltr>1</code> استفاده کنید.
# <br>
# سپس در یک حلقه به ازای هر دور (به تعداد <code>epochs</code>) باید یک‌بار کل مجموعه‌ی آموزشی را بررسی کنید. بنابراین در داخل این حلقه، یک حلقه‌ی دیگر خواهید داشت که هربار یکی از نمونه‌ها را بررسی می‌کند (به دلیل استفاده از روش کاهش گرادیان تصادفی در هر تکرار تنها یک نمونه بررسی و وزن‌ها آپدیت می‌شوند).
# <br>
# به ازای هر نمونه، ابتدا به کمک تابع <code>weighting</code> بردار ویژگی آن را در بردار وزن ضرب نقطه‌ای می‌کنیم تا ورودی وزن‌دار به دست آید. سپس حاصل به‌دست‌آمده را به تابع فعال‌سازی می‌دهیم تا مقدار خروجی مدل را تولید کند. حال با تفریق پیش‌بینی مدل از مقدار (برچسب) واقعی می‌توانیم اختلاف‌شان را به دست آوریم. سپس طبق فرمول‌های معرفی‌شده در درسنامه، با ضرب این اختلاف در نرخ یادگیری و ویژگی‌های ورودی و سپس جمع آن با مقادیر قبلی بردار وزن می‌توانیم به آپدیت بردار وزن بپردازیم.
# <br>
# پیشنهاد می‌شود در آخر هر دور نسبت به چاپ دقت مدل کنونی بر روی مجموعه‌ی آموزشی نیز اقدام کنید. برای این کار کافیست نمونه‌ها را به تابع <code>predict</code> بدهید تا پیش‌بینی مدل تولید شود و سپس به کمک تابع آماده‌ی <code>accuracy_score</code> دقت آن را به دست آورید.
# <br>
# <b>نکته: </b>
# در هیچ‌کدام از توابع خود به غیر از تابع <code>fit</code> چیزی را چاپ (<code>print</code>) نکنید، در غیر این‌صورت سیستم داوری قادر به امتیازدهی به توابع شما نخواهد بود.
# </font>
# </p>

# %%
class Perceptron:

    def __init__(self):
        self.weights = None

    def weighting(self, input):
        return np.dot(input, self.weights)

    def activation(self, weighted_input):
        return 1 if weighted_input >= 0 else -1

    def predict(self, inputs):
        prediction = []
        features_pred = np.c_[np.ones(inputs.shape[0]), inputs]
        for x in features_pred:
            y = self.weighting(x)
            prediction.append(self.activation(y))
        return prediction

    def fit(self, inputs, outputs, learning_rate, epochs):
        features = np.c_[np.ones(inputs.shape[0]), inputs]
        self.weights = np.random.rand(features.shape[1])
        for e in range(epochs):
            for x, y in zip(features, outputs):
                weighted_input = self.weighting(x)
                prediction = self.activation(weighted_input)
                self.weights += learning_rate * (y - prediction) * x
            accuracy = accuracy_score(outputs, self.predict(inputs))
            print(f"Epoch {e+1}/{epochs} - Accuracy: {accuracy:.4f}")
            if accuracy == 1.0:
                break

# %% [markdown]
# <h4 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آموزش مدل
# </font>
# </h4>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir">
#     پس از طراحی ساختار پرسپترون می‌توانید به کمک <code dir=ltr>Perceptron()</code> ابتدا یک نمونه از این کلاس بسازید و سپس تابع <code>fit</code> را با آرگومان‌های مناسب صدا بزنید تا آموزش مدل آغاز شود. این کار را برای هر سه حالت ورودی انجام دهید. پیشنهاد می‌شود مقادیر مختلف نرخ یادگیری مانند 0.1، 0.01، 0.001 و... را آزمایش و مقایسه کنید.
# </font>
# </p>

# %%
perceptron = Perceptron()
perceptron.fit(df1, target_df1, learning_rate= 0.01, epochs= 10000)
# Out:
# Epoch 1/10000 - Accuracy: 0.8100
# Epoch 2/10000 - Accuracy: 0.9700
# Epoch 3/10000 - Accuracy: 0.9900
# Epoch 4/10000 - Accuracy: 0.9900
# Epoch 5/10000 - Accuracy: 1.0000

# %%
perceptron = Perceptron()
perceptron.fit(df2, target_df2, learning_rate= 0.01, epochs= 1000)
# Out:
# Epoch 1/1000 - Accuracy: 0.9400
# Epoch 2/1000 - Accuracy: 1.0000

# %%
perceptron = Perceptron()
perceptron.fit(df3, target_df3, learning_rate= 0.01, epochs= 1000)
# Out:
# Epoch 1/1000 - Accuracy: 0.5400
# Epoch 2/1000 - Accuracy: 0.7800
# Epoch 3/1000 - Accuracy: 0.7800
# Epoch 4/1000 - Accuracy: 0.8200
# Epoch 5/1000 - Accuracy: 0.7700
# Epoch 6/1000 - Accuracy: 0.8400
# Epoch 7/1000 - Accuracy: 0.8800
# Epoch 8/1000 - Accuracy: 0.9200
# Epoch 9/1000 - Accuracy: 0.8700
# Epoch 10/1000 - Accuracy: 0.9200
# Epoch 11/1000 - Accuracy: 0.9000
# Epoch 12/1000 - Accuracy: 0.9300
# Epoch 13/1000 - Accuracy: 0.9400
# Epoch 14/1000 - Accuracy: 0.9200
# Epoch 15/1000 - Accuracy: 0.9500
# Epoch 16/1000 - Accuracy: 0.9600
# Epoch 17/1000 - Accuracy: 0.9500
# Epoch 18/1000 - Accuracy: 0.9700
# Epoch 19/1000 - Accuracy: 0.9600
# Epoch 20/1000 - Accuracy: 0.9600
# Epoch 21/1000 - Accuracy: 0.9700
# Epoch 22/1000 - Accuracy: 0.9800
# Epoch 23/1000 - Accuracy: 0.9500
# Epoch 24/1000 - Accuracy: 0.9600
# Epoch 25/1000 - Accuracy: 0.9700
# Epoch 26/1000 - Accuracy: 0.9800
# Epoch 27/1000 - Accuracy: 0.9800
# Epoch 28/1000 - Accuracy: 0.9800
# Epoch 29/1000 - Accuracy: 0.9800
# Epoch 30/1000 - Accuracy: 0.9800
# Epoch 31/1000 - Accuracy: 0.9500
# Epoch 32/1000 - Accuracy: 0.9800
# Epoch 33/1000 - Accuracy: 0.9800
# Epoch 34/1000 - Accuracy: 0.9500
# Epoch 35/1000 - Accuracy: 0.9800
# Epoch 36/1000 - Accuracy: 0.9800
# Epoch 37/1000 - Accuracy: 0.9500
# Epoch 38/1000 - Accuracy: 0.9500
# Epoch 39/1000 - Accuracy: 0.9500
# Epoch 40/1000 - Accuracy: 0.9800
# Epoch 41/1000 - Accuracy: 0.9800
# Epoch 42/1000 - Accuracy: 0.9800
# Epoch 43/1000 - Accuracy: 0.9500
# Epoch 44/1000 - Accuracy: 0.9600
# Epoch 45/1000 - Accuracy: 0.9600
# Epoch 46/1000 - Accuracy: 0.9800
# Epoch 47/1000 - Accuracy: 0.9800
# Epoch 48/1000 - Accuracy: 0.9600
# Epoch 49/1000 - Accuracy: 0.9600
# Epoch 50/1000 - Accuracy: 0.9600
# Epoch 51/1000 - Accuracy: 0.9800
# Epoch 52/1000 - Accuracy: 0.9800
# Epoch 53/1000 - Accuracy: 0.9600
# Epoch 54/1000 - Accuracy: 0.9600
# Epoch 55/1000 - Accuracy: 0.9600
# Epoch 56/1000 - Accuracy: 0.9800
# Epoch 57/1000 - Accuracy: 0.9800
# Epoch 58/1000 - Accuracy: 0.9800
# Epoch 59/1000 - Accuracy: 0.9600
# Epoch 60/1000 - Accuracy: 0.9600
# Epoch 61/1000 - Accuracy: 0.9800
# Epoch 62/1000 - Accuracy: 0.9800
# Epoch 63/1000 - Accuracy: 0.9600
# Epoch 64/1000 - Accuracy: 0.9600
# Epoch 65/1000 - Accuracy: 0.9600
# Epoch 66/1000 - Accuracy: 0.9600
# Epoch 67/1000 - Accuracy: 0.9800
# Epoch 68/1000 - Accuracy: 0.9800
# Epoch 69/1000 - Accuracy: 0.9600
# Epoch 70/1000 - Accuracy: 0.9600
# Epoch 71/1000 - Accuracy: 0.9600
# Epoch 72/1000 - Accuracy: 0.9600
# Epoch 73/1000 - Accuracy: 0.9800
# Epoch 74/1000 - Accuracy: 0.9800
# Epoch 75/1000 - Accuracy: 0.9600
# Epoch 76/1000 - Accuracy: 0.9600
# Epoch 77/1000 - Accuracy: 0.9500
# Epoch 78/1000 - Accuracy: 0.9800
# Epoch 79/1000 - Accuracy: 0.9900
# Epoch 80/1000 - Accuracy: 0.9800
# Epoch 81/1000 - Accuracy: 0.9800
# Epoch 82/1000 - Accuracy: 0.9500
# Epoch 83/1000 - Accuracy: 0.9600
# Epoch 84/1000 - Accuracy: 0.9500
# Epoch 85/1000 - Accuracy: 0.9500
# Epoch 86/1000 - Accuracy: 0.9500
# Epoch 87/1000 - Accuracy: 0.9600
# Epoch 88/1000 - Accuracy: 0.9500
# Epoch 89/1000 - Accuracy: 0.9500
# Epoch 90/1000 - Accuracy: 0.9500
# Epoch 91/1000 - Accuracy: 0.9600
# Epoch 92/1000 - Accuracy: 0.9500
# Epoch 93/1000 - Accuracy: 0.9600
# Epoch 94/1000 - Accuracy: 0.9500
# Epoch 95/1000 - Accuracy: 0.9500
# Epoch 96/1000 - Accuracy: 0.9500
# Epoch 97/1000 - Accuracy: 0.9600
# Epoch 98/1000 - Accuracy: 0.9500
# Epoch 99/1000 - Accuracy: 0.9700
# Epoch 100/1000 - Accuracy: 0.9700
# Epoch 101/1000 - Accuracy: 0.9600
# Epoch 102/1000 - Accuracy: 0.9600
# Epoch 103/1000 - Accuracy: 0.9600
# Epoch 104/1000 - Accuracy: 0.9600
# Epoch 105/1000 - Accuracy: 0.9600
# Epoch 106/1000 - Accuracy: 0.9600
# Epoch 107/1000 - Accuracy: 0.9500
# Epoch 108/1000 - Accuracy: 0.9900
# Epoch 109/1000 - Accuracy: 0.9700
# Epoch 110/1000 - Accuracy: 0.9500
# Epoch 111/1000 - Accuracy: 0.9500
# Epoch 112/1000 - Accuracy: 0.9500
# Epoch 113/1000 - Accuracy: 0.9500
# Epoch 114/1000 - Accuracy: 0.9500
# Epoch 115/1000 - Accuracy: 0.9600
# Epoch 116/1000 - Accuracy: 0.9600
# Epoch 117/1000 - Accuracy: 0.9500
# Epoch 118/1000 - Accuracy: 0.9600
# Epoch 119/1000 - Accuracy: 0.9500
# Epoch 120/1000 - Accuracy: 0.9500
# Epoch 121/1000 - Accuracy: 0.9500
# Epoch 122/1000 - Accuracy: 0.9500
# Epoch 123/1000 - Accuracy: 0.9600
# Epoch 124/1000 - Accuracy: 0.9500
# Epoch 125/1000 - Accuracy: 0.9600
# Epoch 126/1000 - Accuracy: 0.9500
# Epoch 127/1000 - Accuracy: 0.9500
# Epoch 128/1000 - Accuracy: 0.9500
# Epoch 129/1000 - Accuracy: 0.9500
# Epoch 130/1000 - Accuracy: 0.9600
# Epoch 131/1000 - Accuracy: 0.9600
# Epoch 132/1000 - Accuracy: 0.9500
# Epoch 133/1000 - Accuracy: 0.9600
# Epoch 134/1000 - Accuracy: 0.9500
# Epoch 135/1000 - Accuracy: 0.9500
# Epoch 136/1000 - Accuracy: 0.9500
# Epoch 137/1000 - Accuracy: 0.9500
# Epoch 138/1000 - Accuracy: 0.9600
# Epoch 139/1000 - Accuracy: 0.9500
# Epoch 140/1000 - Accuracy: 0.9600
# Epoch 141/1000 - Accuracy: 0.9500
# Epoch 142/1000 - Accuracy: 0.9500
# Epoch 143/1000 - Accuracy: 0.9500
# Epoch 144/1000 - Accuracy: 0.9500
# Epoch 145/1000 - Accuracy: 0.9600
# Epoch 146/1000 - Accuracy: 0.9600
# Epoch 147/1000 - Accuracy: 0.9500
# Epoch 148/1000 - Accuracy: 0.9600
# Epoch 149/1000 - Accuracy: 0.9500
# Epoch 150/1000 - Accuracy: 0.9500
# Epoch 151/1000 - Accuracy: 0.9700
# Epoch 152/1000 - Accuracy: 0.9600
# Epoch 153/1000 - Accuracy: 0.9600
# Epoch 154/1000 - Accuracy: 0.9600
# Epoch 155/1000 - Accuracy: 0.9600
# Epoch 156/1000 - Accuracy: 0.9600
# Epoch 157/1000 - Accuracy: 0.9600
# Epoch 158/1000 - Accuracy: 0.9600
# Epoch 159/1000 - Accuracy: 0.9600
# Epoch 160/1000 - Accuracy: 0.9500
# Epoch 161/1000 - Accuracy: 0.9500
# Epoch 162/1000 - Accuracy: 0.9500
# Epoch 163/1000 - Accuracy: 0.9500
# Epoch 164/1000 - Accuracy: 0.9500
# Epoch 165/1000 - Accuracy: 0.9500
# Epoch 166/1000 - Accuracy: 0.9500
# Epoch 167/1000 - Accuracy: 0.9600
# Epoch 168/1000 - Accuracy: 0.9600
# Epoch 169/1000 - Accuracy: 0.9500
# Epoch 170/1000 - Accuracy: 0.9500
# Epoch 171/1000 - Accuracy: 0.9500
# Epoch 172/1000 - Accuracy: 0.9500
# Epoch 173/1000 - Accuracy: 0.9600
# Epoch 174/1000 - Accuracy: 0.9600
# Epoch 175/1000 - Accuracy: 0.9500
# Epoch 176/1000 - Accuracy: 0.9500
# Epoch 177/1000 - Accuracy: 0.9500
# Epoch 178/1000 - Accuracy: 0.9500
# Epoch 179/1000 - Accuracy: 0.9600
# Epoch 180/1000 - Accuracy: 0.9500
# Epoch 181/1000 - Accuracy: 0.9600
# Epoch 182/1000 - Accuracy: 0.9600
# Epoch 183/1000 - Accuracy: 0.9500
# Epoch 184/1000 - Accuracy: 0.9500
# Epoch 185/1000 - Accuracy: 0.9500
# Epoch 186/1000 - Accuracy: 0.9500
# Epoch 187/1000 - Accuracy: 0.9600
# Epoch 188/1000 - Accuracy: 0.9600
# Epoch 189/1000 - Accuracy: 0.9500
# Epoch 190/1000 - Accuracy: 0.9600
# Epoch 191/1000 - Accuracy: 0.9500
# Epoch 192/1000 - Accuracy: 0.9500
# Epoch 193/1000 - Accuracy: 0.9500
# Epoch 194/1000 - Accuracy: 0.9500
# Epoch 195/1000 - Accuracy: 0.9600
# Epoch 196/1000 - Accuracy: 0.9600
# Epoch 197/1000 - Accuracy: 0.9500
# Epoch 198/1000 - Accuracy: 0.9600
# Epoch 199/1000 - Accuracy: 0.9600
# Epoch 200/1000 - Accuracy: 0.9500
# Epoch 201/1000 - Accuracy: 0.9500
# Epoch 202/1000 - Accuracy: 0.9500
# Epoch 203/1000 - Accuracy: 0.9500
# Epoch 204/1000 - Accuracy: 0.9600
# Epoch 205/1000 - Accuracy: 0.9500
# Epoch 206/1000 - Accuracy: 0.9600
# Epoch 207/1000 - Accuracy: 0.9600
# Epoch 208/1000 - Accuracy: 0.9500
# Epoch 209/1000 - Accuracy: 0.9500
# Epoch 210/1000 - Accuracy: 0.9500
# Epoch 211/1000 - Accuracy: 0.9500
# Epoch 212/1000 - Accuracy: 0.9600
# Epoch 213/1000 - Accuracy: 0.9600
# Epoch 214/1000 - Accuracy: 0.9500
# Epoch 215/1000 - Accuracy: 0.9500
# Epoch 216/1000 - Accuracy: 0.9500
# Epoch 217/1000 - Accuracy: 0.9500
# Epoch 218/1000 - Accuracy: 0.9600
# Epoch 219/1000 - Accuracy: 0.9500
# Epoch 220/1000 - Accuracy: 0.9600
# Epoch 221/1000 - Accuracy: 0.9600
# Epoch 222/1000 - Accuracy: 0.9500
# Epoch 223/1000 - Accuracy: 0.9500
# Epoch 224/1000 - Accuracy: 0.9500
# Epoch 225/1000 - Accuracy: 0.9500
# Epoch 226/1000 - Accuracy: 0.9500
# Epoch 227/1000 - Accuracy: 0.9600
# Epoch 228/1000 - Accuracy: 0.9600
# Epoch 229/1000 - Accuracy: 0.9600
# Epoch 230/1000 - Accuracy: 0.9600
# Epoch 231/1000 - Accuracy: 0.9600
# Epoch 232/1000 - Accuracy: 0.9600
# Epoch 233/1000 - Accuracy: 0.9600
# Epoch 234/1000 - Accuracy: 0.9600
# Epoch 235/1000 - Accuracy: 0.9600
# Epoch 236/1000 - Accuracy: 0.9700
# Epoch 237/1000 - Accuracy: 0.9500
# Epoch 238/1000 - Accuracy: 0.9500
# Epoch 239/1000 - Accuracy: 0.9600
# Epoch 240/1000 - Accuracy: 0.9600
# Epoch 241/1000 - Accuracy: 0.9600
# Epoch 242/1000 - Accuracy: 0.9600
# Epoch 243/1000 - Accuracy: 0.9600
# Epoch 244/1000 - Accuracy: 0.9600
# Epoch 245/1000 - Accuracy: 0.9600
# Epoch 246/1000 - Accuracy: 0.9700
# Epoch 247/1000 - Accuracy: 0.9500
# Epoch 248/1000 - Accuracy: 0.9500
# Epoch 249/1000 - Accuracy: 0.9600
# Epoch 250/1000 - Accuracy: 0.9600
# Epoch 251/1000 - Accuracy: 0.9600
# Epoch 252/1000 - Accuracy: 0.9600
# Epoch 253/1000 - Accuracy: 0.9500
# Epoch 254/1000 - Accuracy: 0.9500
# Epoch 255/1000 - Accuracy: 0.9500
# Epoch 256/1000 - Accuracy: 0.9500
# Epoch 257/1000 - Accuracy: 0.9500
# Epoch 258/1000 - Accuracy: 0.9500
# Epoch 259/1000 - Accuracy: 0.9500
# Epoch 260/1000 - Accuracy: 0.9500
# Epoch 261/1000 - Accuracy: 0.9500
# Epoch 262/1000 - Accuracy: 0.9500
# Epoch 263/1000 - Accuracy: 0.9600
# Epoch 264/1000 - Accuracy: 0.9500
# Epoch 265/1000 - Accuracy: 0.9500
# Epoch 266/1000 - Accuracy: 0.9500
# Epoch 267/1000 - Accuracy: 0.9500
# Epoch 268/1000 - Accuracy: 0.9600
# Epoch 269/1000 - Accuracy: 0.9600
# Epoch 270/1000 - Accuracy: 0.9500
# Epoch 271/1000 - Accuracy: 0.9600
# Epoch 272/1000 - Accuracy: 0.9500
# Epoch 273/1000 - Accuracy: 0.9500
# Epoch 274/1000 - Accuracy: 0.9500
# Epoch 275/1000 - Accuracy: 0.9500
# Epoch 276/1000 - Accuracy: 0.9600
# Epoch 277/1000 - Accuracy: 0.9600
# Epoch 278/1000 - Accuracy: 0.9500
# Epoch 279/1000 - Accuracy: 0.9600
# Epoch 280/1000 - Accuracy: 0.9600
# Epoch 281/1000 - Accuracy: 0.9500
# Epoch 282/1000 - Accuracy: 0.9500
# Epoch 283/1000 - Accuracy: 0.9500
# Epoch 284/1000 - Accuracy: 0.9500
# Epoch 285/1000 - Accuracy: 0.9600
# Epoch 286/1000 - Accuracy: 0.9500
# Epoch 287/1000 - Accuracy: 0.9600
# Epoch 288/1000 - Accuracy: 0.9600
# Epoch 289/1000 - Accuracy: 0.9500
# Epoch 290/1000 - Accuracy: 0.9500
# Epoch 291/1000 - Accuracy: 0.9500
# Epoch 292/1000 - Accuracy: 0.9500
# Epoch 293/1000 - Accuracy: 0.9600
# Epoch 294/1000 - Accuracy: 0.9600
# Epoch 295/1000 - Accuracy: 0.9600
# Epoch 296/1000 - Accuracy: 0.9600
# Epoch 297/1000 - Accuracy: 0.9600
# Epoch 298/1000 - Accuracy: 0.9500
# Epoch 299/1000 - Accuracy: 0.9600
# Epoch 300/1000 - Accuracy: 0.9500
# Epoch 301/1000 - Accuracy: 0.9500
# Epoch 302/1000 - Accuracy: 0.9500
# Epoch 303/1000 - Accuracy: 0.9700
# Epoch 304/1000 - Accuracy: 0.9700
# Epoch 305/1000 - Accuracy: 0.9600
# Epoch 306/1000 - Accuracy: 0.9600
# Epoch 307/1000 - Accuracy: 0.9600
# Epoch 308/1000 - Accuracy: 0.9700
# Epoch 309/1000 - Accuracy: 0.9500
# Epoch 310/1000 - Accuracy: 0.9500
# Epoch 311/1000 - Accuracy: 0.9600
# Epoch 312/1000 - Accuracy: 0.9600
# Epoch 313/1000 - Accuracy: 0.9600
# Epoch 314/1000 - Accuracy: 0.9600
# Epoch 315/1000 - Accuracy: 0.9500
# Epoch 316/1000 - Accuracy: 0.9500
# Epoch 317/1000 - Accuracy: 0.9600
# Epoch 318/1000 - Accuracy: 0.9500
# Epoch 319/1000 - Accuracy: 0.9600
# Epoch 320/1000 - Accuracy: 0.9600
# Epoch 321/1000 - Accuracy: 0.9600
# Epoch 322/1000 - Accuracy: 0.9700
# Epoch 323/1000 - Accuracy: 0.9500
# Epoch 324/1000 - Accuracy: 0.9500
# Epoch 325/1000 - Accuracy: 0.9600
# Epoch 326/1000 - Accuracy: 0.9600
# Epoch 327/1000 - Accuracy: 0.9500
# Epoch 328/1000 - Accuracy: 0.9600
# Epoch 329/1000 - Accuracy: 0.9600
# Epoch 330/1000 - Accuracy: 0.9600
# Epoch 331/1000 - Accuracy: 0.9800
# Epoch 332/1000 - Accuracy: 0.9600
# Epoch 333/1000 - Accuracy: 0.9600
# Epoch 334/1000 - Accuracy: 0.9500
# Epoch 335/1000 - Accuracy: 0.9700
# Epoch 336/1000 - Accuracy: 0.9500
# Epoch 337/1000 - Accuracy: 0.9500
# Epoch 338/1000 - Accuracy: 0.9500
# Epoch 339/1000 - Accuracy: 0.9500
# Epoch 340/1000 - Accuracy: 0.9500
# Epoch 341/1000 - Accuracy: 0.9500
# Epoch 342/1000 - Accuracy: 0.9500
# Epoch 343/1000 - Accuracy: 0.9500
# Epoch 344/1000 - Accuracy: 0.9500
# Epoch 345/1000 - Accuracy: 0.9500
# Epoch 346/1000 - Accuracy: 0.9500
# Epoch 347/1000 - Accuracy: 0.9600
# Epoch 348/1000 - Accuracy: 0.9500
# Epoch 349/1000 - Accuracy: 0.9500
# Epoch 350/1000 - Accuracy: 0.9500
# Epoch 351/1000 - Accuracy: 0.9500
# Epoch 352/1000 - Accuracy: 0.9500
# Epoch 353/1000 - Accuracy: 0.9700
# Epoch 354/1000 - Accuracy: 0.9700
# Epoch 355/1000 - Accuracy: 0.9500
# Epoch 356/1000 - Accuracy: 0.9600
# Epoch 357/1000 - Accuracy: 0.9600
# Epoch 358/1000 - Accuracy: 0.9600
# Epoch 359/1000 - Accuracy: 0.9500
# Epoch 360/1000 - Accuracy: 0.9600
# Epoch 361/1000 - Accuracy: 0.9500
# Epoch 362/1000 - Accuracy: 0.9500
# Epoch 363/1000 - Accuracy: 0.9600
# Epoch 364/1000 - Accuracy: 0.9500
# Epoch 365/1000 - Accuracy: 0.9600
# Epoch 366/1000 - Accuracy: 0.9500
# Epoch 367/1000 - Accuracy: 0.9600
# Epoch 368/1000 - Accuracy: 0.9500
# Epoch 369/1000 - Accuracy: 0.9500
# Epoch 370/1000 - Accuracy: 0.9600
# Epoch 371/1000 - Accuracy: 0.9600
# Epoch 372/1000 - Accuracy: 0.9600
# Epoch 373/1000 - Accuracy: 0.9500
# Epoch 374/1000 - Accuracy: 0.9600
# Epoch 375/1000 - Accuracy: 0.9500
# Epoch 376/1000 - Accuracy: 0.9600
# Epoch 377/1000 - Accuracy: 0.9500
# Epoch 378/1000 - Accuracy: 0.9600
# Epoch 379/1000 - Accuracy: 0.9500
# Epoch 380/1000 - Accuracy: 0.9600
# Epoch 381/1000 - Accuracy: 0.9500
# Epoch 382/1000 - Accuracy: 0.9500
# Epoch 383/1000 - Accuracy: 0.9500
# Epoch 384/1000 - Accuracy: 0.9600
# Epoch 385/1000 - Accuracy: 0.9600
# Epoch 386/1000 - Accuracy: 0.9600
# Epoch 387/1000 - Accuracy: 0.9600
# Epoch 388/1000 - Accuracy: 0.9500
# Epoch 389/1000 - Accuracy: 0.9600
# Epoch 390/1000 - Accuracy: 0.9500
# Epoch 391/1000 - Accuracy: 0.9500
# Epoch 392/1000 - Accuracy: 0.9600
# Epoch 393/1000 - Accuracy: 0.9500
# Epoch 394/1000 - Accuracy: 0.9700
# Epoch 395/1000 - Accuracy: 0.9500
# Epoch 396/1000 - Accuracy: 0.9600
# Epoch 397/1000 - Accuracy: 0.9700
# Epoch 398/1000 - Accuracy: 0.9600
# Epoch 399/1000 - Accuracy: 0.9600
# Epoch 400/1000 - Accuracy: 0.9600
# Epoch 401/1000 - Accuracy: 0.9500
# Epoch 402/1000 - Accuracy: 0.9600
# Epoch 403/1000 - Accuracy: 0.9500
# Epoch 404/1000 - Accuracy: 0.9700
# Epoch 405/1000 - Accuracy: 0.9600
# Epoch 406/1000 - Accuracy: 0.9600
# Epoch 407/1000 - Accuracy: 0.9500
# Epoch 408/1000 - Accuracy: 0.9600
# Epoch 409/1000 - Accuracy: 0.9500
# Epoch 410/1000 - Accuracy: 0.9600
# Epoch 411/1000 - Accuracy: 0.9500
# Epoch 412/1000 - Accuracy: 0.9700
# Epoch 413/1000 - Accuracy: 0.9600
# Epoch 414/1000 - Accuracy: 0.9600
# Epoch 415/1000 - Accuracy: 0.9700
# Epoch 416/1000 - Accuracy: 0.9600
# Epoch 417/1000 - Accuracy: 0.9700
# Epoch 418/1000 - Accuracy: 0.9500
# Epoch 419/1000 - Accuracy: 0.9500
# Epoch 420/1000 - Accuracy: 0.9500
# Epoch 421/1000 - Accuracy: 0.9500
# Epoch 422/1000 - Accuracy: 0.9500
# Epoch 423/1000 - Accuracy: 0.9500
# Epoch 424/1000 - Accuracy: 0.9500
# Epoch 425/1000 - Accuracy: 0.9500
# Epoch 426/1000 - Accuracy: 0.9500
# Epoch 427/1000 - Accuracy: 0.9500
# Epoch 428/1000 - Accuracy: 0.9500
# Epoch 429/1000 - Accuracy: 0.9600
# Epoch 430/1000 - Accuracy: 0.9600
# Epoch 431/1000 - Accuracy: 0.9500
# Epoch 432/1000 - Accuracy: 0.9600
# Epoch 433/1000 - Accuracy: 0.9500
# Epoch 434/1000 - Accuracy: 0.9500
# Epoch 435/1000 - Accuracy: 0.9700
# Epoch 436/1000 - Accuracy: 0.9500
# Epoch 437/1000 - Accuracy: 0.9700
# Epoch 438/1000 - Accuracy: 0.9500
# Epoch 439/1000 - Accuracy: 0.9700
# Epoch 440/1000 - Accuracy: 0.9500
# Epoch 441/1000 - Accuracy: 0.9500
# Epoch 442/1000 - Accuracy: 0.9500
# Epoch 443/1000 - Accuracy: 0.9600
# Epoch 444/1000 - Accuracy: 0.9600
# Epoch 445/1000 - Accuracy: 0.9600
# Epoch 446/1000 - Accuracy: 0.9500
# Epoch 447/1000 - Accuracy: 0.9600
# Epoch 448/1000 - Accuracy: 0.9500
# Epoch 449/1000 - Accuracy: 0.9500
# Epoch 450/1000 - Accuracy: 0.9600
# Epoch 451/1000 - Accuracy: 0.9500
# Epoch 452/1000 - Accuracy: 0.9500
# Epoch 453/1000 - Accuracy: 0.9500
# Epoch 454/1000 - Accuracy: 0.9500
# Epoch 455/1000 - Accuracy: 0.9500
# Epoch 456/1000 - Accuracy: 0.9500
# Epoch 457/1000 - Accuracy: 0.9600
# Epoch 458/1000 - Accuracy: 0.9500
# Epoch 459/1000 - Accuracy: 0.9600
# Epoch 460/1000 - Accuracy: 0.9500
# Epoch 461/1000 - Accuracy: 0.9600
# Epoch 462/1000 - Accuracy: 0.9500
# Epoch 463/1000 - Accuracy: 0.9600
# Epoch 464/1000 - Accuracy: 0.9500
# Epoch 465/1000 - Accuracy: 0.9500
# Epoch 466/1000 - Accuracy: 0.9600
# Epoch 467/1000 - Accuracy: 0.9600
# Epoch 468/1000 - Accuracy: 0.9600
# Epoch 469/1000 - Accuracy: 0.9500
# Epoch 470/1000 - Accuracy: 0.9500
# Epoch 471/1000 - Accuracy: 0.9500
# Epoch 472/1000 - Accuracy: 0.9500
# Epoch 473/1000 - Accuracy: 0.9500
# Epoch 474/1000 - Accuracy: 0.9600
# Epoch 475/1000 - Accuracy: 0.9500
# Epoch 476/1000 - Accuracy: 0.9700
# Epoch 477/1000 - Accuracy: 0.9600
# Epoch 478/1000 - Accuracy: 0.9600
# Epoch 479/1000 - Accuracy: 0.9500
# Epoch 480/1000 - Accuracy: 0.9500
# Epoch 481/1000 - Accuracy: 0.9500
# Epoch 482/1000 - Accuracy: 0.9600
# Epoch 483/1000 - Accuracy: 0.9500
# Epoch 484/1000 - Accuracy: 0.9700
# Epoch 485/1000 - Accuracy: 0.9600
# Epoch 486/1000 - Accuracy: 0.9600
# Epoch 487/1000 - Accuracy: 0.9600
# Epoch 488/1000 - Accuracy: 0.9500
# Epoch 489/1000 - Accuracy: 0.9500
# Epoch 490/1000 - Accuracy: 0.9500
# Epoch 491/1000 - Accuracy: 0.9500
# Epoch 492/1000 - Accuracy: 0.9600
# Epoch 493/1000 - Accuracy: 0.9500
# Epoch 494/1000 - Accuracy: 0.9700
# Epoch 495/1000 - Accuracy: 0.9600
# Epoch 496/1000 - Accuracy: 0.9600
# Epoch 497/1000 - Accuracy: 0.9600
# Epoch 498/1000 - Accuracy: 0.9500
# Epoch 499/1000 - Accuracy: 0.9600
# Epoch 500/1000 - Accuracy: 0.9600
# Epoch 501/1000 - Accuracy: 0.9600
# Epoch 502/1000 - Accuracy: 0.9500
# Epoch 503/1000 - Accuracy: 0.9600
# Epoch 504/1000 - Accuracy: 0.9500
# Epoch 505/1000 - Accuracy: 0.9600
# Epoch 506/1000 - Accuracy: 0.9500
# Epoch 507/1000 - Accuracy: 0.9700
# Epoch 508/1000 - Accuracy: 0.9600
# Epoch 509/1000 - Accuracy: 0.9600
# Epoch 510/1000 - Accuracy: 0.9500
# Epoch 511/1000 - Accuracy: 0.9600
# Epoch 512/1000 - Accuracy: 0.9500
# Epoch 513/1000 - Accuracy: 0.9600
# Epoch 514/1000 - Accuracy: 0.9500
# Epoch 515/1000 - Accuracy: 0.9700
# Epoch 516/1000 - Accuracy: 0.9600
# Epoch 517/1000 - Accuracy: 0.9600
# Epoch 518/1000 - Accuracy: 0.9600
# Epoch 519/1000 - Accuracy: 0.9500
# Epoch 520/1000 - Accuracy: 0.9600
# Epoch 521/1000 - Accuracy: 0.9500
# Epoch 522/1000 - Accuracy: 0.9500
# Epoch 523/1000 - Accuracy: 0.9700
# Epoch 524/1000 - Accuracy: 0.9600
# Epoch 525/1000 - Accuracy: 0.9600
# Epoch 526/1000 - Accuracy: 0.9600
# Epoch 527/1000 - Accuracy: 0.9500
# Epoch 528/1000 - Accuracy: 0.9600
# Epoch 529/1000 - Accuracy: 0.9500
# Epoch 530/1000 - Accuracy: 0.9700
# Epoch 531/1000 - Accuracy: 0.9600
# Epoch 532/1000 - Accuracy: 0.9500
# Epoch 533/1000 - Accuracy: 0.9500
# Epoch 534/1000 - Accuracy: 0.9500
# Epoch 535/1000 - Accuracy: 0.9500
# Epoch 536/1000 - Accuracy: 0.9500
# Epoch 537/1000 - Accuracy: 0.9500
# Epoch 538/1000 - Accuracy: 0.9500
# Epoch 539/1000 - Accuracy: 0.9500
# Epoch 540/1000 - Accuracy: 0.9500
# Epoch 541/1000 - Accuracy: 0.9500
# Epoch 542/1000 - Accuracy: 0.9500
# Epoch 543/1000 - Accuracy: 0.9600
# Epoch 544/1000 - Accuracy: 0.9500
# Epoch 545/1000 - Accuracy: 0.9700
# Epoch 546/1000 - Accuracy: 0.9500
# Epoch 547/1000 - Accuracy: 0.9700
# Epoch 548/1000 - Accuracy: 0.9500
# Epoch 549/1000 - Accuracy: 0.9600
# Epoch 550/1000 - Accuracy: 0.9600
# Epoch 551/1000 - Accuracy: 0.9500
# Epoch 552/1000 - Accuracy: 0.9600
# Epoch 553/1000 - Accuracy: 0.9500
# Epoch 554/1000 - Accuracy: 0.9700
# Epoch 555/1000 - Accuracy: 0.9500
# Epoch 556/1000 - Accuracy: 0.9700
# Epoch 557/1000 - Accuracy: 0.9500
# Epoch 558/1000 - Accuracy: 0.9700
# Epoch 559/1000 - Accuracy: 0.9600
# Epoch 560/1000 - Accuracy: 0.9500
# Epoch 561/1000 - Accuracy: 0.9500
# Epoch 562/1000 - Accuracy: 0.9600
# Epoch 563/1000 - Accuracy: 0.9600
# Epoch 564/1000 - Accuracy: 0.9500
# Epoch 565/1000 - Accuracy: 0.9600
# Epoch 566/1000 - Accuracy: 0.9500
# Epoch 567/1000 - Accuracy: 0.9600
# Epoch 568/1000 - Accuracy: 0.9500
# Epoch 569/1000 - Accuracy: 0.9600
# Epoch 570/1000 - Accuracy: 0.9500
# Epoch 571/1000 - Accuracy: 0.9500
# Epoch 572/1000 - Accuracy: 0.9700
# Epoch 573/1000 - Accuracy: 0.9500
# Epoch 574/1000 - Accuracy: 0.9500
# Epoch 575/1000 - Accuracy: 0.9600
# Epoch 576/1000 - Accuracy: 0.9600
# Epoch 577/1000 - Accuracy: 0.9600
# Epoch 578/1000 - Accuracy: 0.9500
# Epoch 579/1000 - Accuracy: 0.9600
# Epoch 580/1000 - Accuracy: 0.9500
# Epoch 581/1000 - Accuracy: 0.9600
# Epoch 582/1000 - Accuracy: 0.9500
# Epoch 583/1000 - Accuracy: 0.9600
# Epoch 584/1000 - Accuracy: 0.9500
# Epoch 585/1000 - Accuracy: 0.9700
# Epoch 586/1000 - Accuracy: 0.9600
# Epoch 587/1000 - Accuracy: 0.9600
# Epoch 588/1000 - Accuracy: 0.9600
# Epoch 589/1000 - Accuracy: 0.9500
# Epoch 590/1000 - Accuracy: 0.9500
# Epoch 591/1000 - Accuracy: 0.9600
# Epoch 592/1000 - Accuracy: 0.9500
# Epoch 593/1000 - Accuracy: 0.9600
# Epoch 594/1000 - Accuracy: 0.9500
# Epoch 595/1000 - Accuracy: 0.9700
# Epoch 596/1000 - Accuracy: 0.9600
# Epoch 597/1000 - Accuracy: 0.9600
# Epoch 598/1000 - Accuracy: 0.9600
# Epoch 599/1000 - Accuracy: 0.9500
# Epoch 600/1000 - Accuracy: 0.9700
# Epoch 601/1000 - Accuracy: 0.9500
# Epoch 602/1000 - Accuracy: 0.9500
# Epoch 603/1000 - Accuracy: 0.9500
# Epoch 604/1000 - Accuracy: 0.9500
# Epoch 605/1000 - Accuracy: 0.9500
# Epoch 606/1000 - Accuracy: 0.9600
# Epoch 607/1000 - Accuracy: 0.9500
# Epoch 608/1000 - Accuracy: 0.9700
# Epoch 609/1000 - Accuracy: 0.9500
# Epoch 610/1000 - Accuracy: 0.9500
# Epoch 611/1000 - Accuracy: 0.9500
# Epoch 612/1000 - Accuracy: 0.9500
# Epoch 613/1000 - Accuracy: 0.9500
# Epoch 614/1000 - Accuracy: 0.9500
# Epoch 615/1000 - Accuracy: 0.9500
# Epoch 616/1000 - Accuracy: 0.9700
# Epoch 617/1000 - Accuracy: 0.9600
# Epoch 618/1000 - Accuracy: 0.9500
# Epoch 619/1000 - Accuracy: 0.9500
# Epoch 620/1000 - Accuracy: 0.9500
# Epoch 621/1000 - Accuracy: 0.9500
# Epoch 622/1000 - Accuracy: 0.9500
# Epoch 623/1000 - Accuracy: 0.9500
# Epoch 624/1000 - Accuracy: 0.9700
# Epoch 625/1000 - Accuracy: 0.9600
# Epoch 626/1000 - Accuracy: 0.9600
# Epoch 627/1000 - Accuracy: 0.9600
# Epoch 628/1000 - Accuracy: 0.9500
# Epoch 629/1000 - Accuracy: 0.9500
# Epoch 630/1000 - Accuracy: 0.9500
# Epoch 631/1000 - Accuracy: 0.9600
# Epoch 632/1000 - Accuracy: 0.9600
# Epoch 633/1000 - Accuracy: 0.9600
# Epoch 634/1000 - Accuracy: 0.9500
# Epoch 635/1000 - Accuracy: 0.9600
# Epoch 636/1000 - Accuracy: 0.9500
# Epoch 637/1000 - Accuracy: 0.9600
# Epoch 638/1000 - Accuracy: 0.9500
# Epoch 639/1000 - Accuracy: 0.9600
# Epoch 640/1000 - Accuracy: 0.9600
# Epoch 641/1000 - Accuracy: 0.9600
# Epoch 642/1000 - Accuracy: 0.9500
# Epoch 643/1000 - Accuracy: 0.9600
# Epoch 644/1000 - Accuracy: 0.9500
# Epoch 645/1000 - Accuracy: 0.9600
# Epoch 646/1000 - Accuracy: 0.9500
# Epoch 647/1000 - Accuracy: 0.9700
# Epoch 648/1000 - Accuracy: 0.9600
# Epoch 649/1000 - Accuracy: 0.9600
# Epoch 650/1000 - Accuracy: 0.9600
# Epoch 651/1000 - Accuracy: 0.9500
# Epoch 652/1000 - Accuracy: 0.9700
# Epoch 653/1000 - Accuracy: 0.9600
# Epoch 654/1000 - Accuracy: 0.9600
# Epoch 655/1000 - Accuracy: 0.9600
# Epoch 656/1000 - Accuracy: 0.9500
# Epoch 657/1000 - Accuracy: 0.9600
# Epoch 658/1000 - Accuracy: 0.9500
# Epoch 659/1000 - Accuracy: 0.9700
# Epoch 660/1000 - Accuracy: 0.9600
# Epoch 661/1000 - Accuracy: 0.9600
# Epoch 662/1000 - Accuracy: 0.9700
# Epoch 663/1000 - Accuracy: 0.9600
# Epoch 664/1000 - Accuracy: 0.9600
# Epoch 665/1000 - Accuracy: 0.9600
# Epoch 666/1000 - Accuracy: 0.9500
# Epoch 667/1000 - Accuracy: 0.9600
# Epoch 668/1000 - Accuracy: 0.9500
# Epoch 669/1000 - Accuracy: 0.9700
# Epoch 670/1000 - Accuracy: 0.9600
# Epoch 671/1000 - Accuracy: 0.9600
# Epoch 672/1000 - Accuracy: 0.9600
# Epoch 673/1000 - Accuracy: 0.9500
# Epoch 674/1000 - Accuracy: 0.9600
# Epoch 675/1000 - Accuracy: 0.9600
# Epoch 676/1000 - Accuracy: 0.9600
# Epoch 677/1000 - Accuracy: 0.9600
# Epoch 678/1000 - Accuracy: 0.9700
# Epoch 679/1000 - Accuracy: 0.9500
# Epoch 680/1000 - Accuracy: 0.9600
# Epoch 681/1000 - Accuracy: 0.9600
# Epoch 682/1000 - Accuracy: 0.9600
# Epoch 683/1000 - Accuracy: 0.9500
# Epoch 684/1000 - Accuracy: 0.9600
# Epoch 685/1000 - Accuracy: 0.9500
# Epoch 686/1000 - Accuracy: 0.9700
# Epoch 687/1000 - Accuracy: 0.9600
# Epoch 688/1000 - Accuracy: 0.9600
# Epoch 689/1000 - Accuracy: 0.9600
# Epoch 690/1000 - Accuracy: 0.9600
# Epoch 691/1000 - Accuracy: 0.9500
# Epoch 692/1000 - Accuracy: 0.9600
# Epoch 693/1000 - Accuracy: 0.9600
# Epoch 694/1000 - Accuracy: 0.9600
# Epoch 695/1000 - Accuracy: 0.9700
# Epoch 696/1000 - Accuracy: 0.9500
# Epoch 697/1000 - Accuracy: 0.9600
# Epoch 698/1000 - Accuracy: 0.9600
# Epoch 699/1000 - Accuracy: 0.9600
# Epoch 700/1000 - Accuracy: 0.9700
# Epoch 701/1000 - Accuracy: 0.9600
# Epoch 702/1000 - Accuracy: 0.9600
# Epoch 703/1000 - Accuracy: 0.9600
# Epoch 704/1000 - Accuracy: 0.9500
# Epoch 705/1000 - Accuracy: 0.9600
# Epoch 706/1000 - Accuracy: 0.9600
# Epoch 707/1000 - Accuracy: 0.9600
# Epoch 708/1000 - Accuracy: 0.9600
# Epoch 709/1000 - Accuracy: 0.9600
# Epoch 710/1000 - Accuracy: 0.9500
# Epoch 711/1000 - Accuracy: 0.9600
# Epoch 712/1000 - Accuracy: 0.9600
# Epoch 713/1000 - Accuracy: 0.9600
# Epoch 714/1000 - Accuracy: 0.9700
# Epoch 715/1000 - Accuracy: 0.9500
# Epoch 716/1000 - Accuracy: 0.9500
# Epoch 717/1000 - Accuracy: 0.9500
# Epoch 718/1000 - Accuracy: 0.9500
# Epoch 719/1000 - Accuracy: 0.9600
# Epoch 720/1000 - Accuracy: 0.9600
# Epoch 721/1000 - Accuracy: 0.9500
# Epoch 722/1000 - Accuracy: 0.9500
# Epoch 723/1000 - Accuracy: 0.9500
# Epoch 724/1000 - Accuracy: 0.9500
# Epoch 725/1000 - Accuracy: 0.9500
# Epoch 726/1000 - Accuracy: 0.9500
# Epoch 727/1000 - Accuracy: 0.9500
# Epoch 728/1000 - Accuracy: 0.9500
# Epoch 729/1000 - Accuracy: 0.9500
# Epoch 730/1000 - Accuracy: 0.9500
# Epoch 731/1000 - Accuracy: 0.9500
# Epoch 732/1000 - Accuracy: 0.9600
# Epoch 733/1000 - Accuracy: 0.9500
# Epoch 734/1000 - Accuracy: 0.9700
# Epoch 735/1000 - Accuracy: 0.9500
# Epoch 736/1000 - Accuracy: 0.9600
# Epoch 737/1000 - Accuracy: 0.9500
# Epoch 738/1000 - Accuracy: 0.9700
# Epoch 739/1000 - Accuracy: 0.9600
# Epoch 740/1000 - Accuracy: 0.9500
# Epoch 741/1000 - Accuracy: 0.9600
# Epoch 742/1000 - Accuracy: 0.9500
# Epoch 743/1000 - Accuracy: 0.9700
# Epoch 744/1000 - Accuracy: 0.9600
# Epoch 745/1000 - Accuracy: 0.9500
# Epoch 746/1000 - Accuracy: 0.9600
# Epoch 747/1000 - Accuracy: 0.9500
# Epoch 748/1000 - Accuracy: 0.9700
# Epoch 749/1000 - Accuracy: 0.9500
# Epoch 750/1000 - Accuracy: 0.9700
# Epoch 751/1000 - Accuracy: 0.9600
# Epoch 752/1000 - Accuracy: 0.9500
# Epoch 753/1000 - Accuracy: 0.9600
# Epoch 754/1000 - Accuracy: 0.9500
# Epoch 755/1000 - Accuracy: 0.9700
# Epoch 756/1000 - Accuracy: 0.9600
# Epoch 757/1000 - Accuracy: 0.9500
# Epoch 758/1000 - Accuracy: 0.9600
# Epoch 759/1000 - Accuracy: 0.9500
# Epoch 760/1000 - Accuracy: 0.9600
# Epoch 761/1000 - Accuracy: 0.9500
# Epoch 762/1000 - Accuracy: 0.9700
# Epoch 763/1000 - Accuracy: 0.9600
# Epoch 764/1000 - Accuracy: 0.9500
# Epoch 765/1000 - Accuracy: 0.9600
# Epoch 766/1000 - Accuracy: 0.9500
# Epoch 767/1000 - Accuracy: 0.9700
# Epoch 768/1000 - Accuracy: 0.9600
# Epoch 769/1000 - Accuracy: 0.9500
# Epoch 770/1000 - Accuracy: 0.9600
# Epoch 771/1000 - Accuracy: 0.9500
# Epoch 772/1000 - Accuracy: 0.9700
# Epoch 773/1000 - Accuracy: 0.9500
# Epoch 774/1000 - Accuracy: 0.9700
# Epoch 775/1000 - Accuracy: 0.9600
# Epoch 776/1000 - Accuracy: 0.9500
# Epoch 777/1000 - Accuracy: 0.9600
# Epoch 778/1000 - Accuracy: 0.9500
# Epoch 779/1000 - Accuracy: 0.9700
# Epoch 780/1000 - Accuracy: 0.9600
# Epoch 781/1000 - Accuracy: 0.9500
# Epoch 782/1000 - Accuracy: 0.9600
# Epoch 783/1000 - Accuracy: 0.9500
# Epoch 784/1000 - Accuracy: 0.9700
# Epoch 785/1000 - Accuracy: 0.9500
# Epoch 786/1000 - Accuracy: 0.9600
# Epoch 787/1000 - Accuracy: 0.9500
# Epoch 788/1000 - Accuracy: 0.9800
# Epoch 789/1000 - Accuracy: 0.9700
# Epoch 790/1000 - Accuracy: 0.9500
# Epoch 791/1000 - Accuracy: 0.9600
# Epoch 792/1000 - Accuracy: 0.9500
# Epoch 793/1000 - Accuracy: 0.9800
# Epoch 794/1000 - Accuracy: 0.9700
# Epoch 795/1000 - Accuracy: 0.9500
# Epoch 796/1000 - Accuracy: 0.9800
# Epoch 797/1000 - Accuracy: 0.9800
# Epoch 798/1000 - Accuracy: 0.9700
# Epoch 799/1000 - Accuracy: 0.9500
# Epoch 800/1000 - Accuracy: 0.9500
# Epoch 801/1000 - Accuracy: 0.9800
# Epoch 802/1000 - Accuracy: 0.9700
# Epoch 803/1000 - Accuracy: 0.9500
# Epoch 804/1000 - Accuracy: 0.9800
# Epoch 805/1000 - Accuracy: 0.9800
# Epoch 806/1000 - Accuracy: 0.9700
# Epoch 807/1000 - Accuracy: 0.9500
# Epoch 808/1000 - Accuracy: 0.9600
# Epoch 809/1000 - Accuracy: 0.9500
# Epoch 810/1000 - Accuracy: 0.9800
# Epoch 811/1000 - Accuracy: 0.9700
# Epoch 812/1000 - Accuracy: 0.9500
# Epoch 813/1000 - Accuracy: 0.9500
# Epoch 814/1000 - Accuracy: 0.9800
# Epoch 815/1000 - Accuracy: 0.9700
# Epoch 816/1000 - Accuracy: 0.9500
# Epoch 817/1000 - Accuracy: 0.9800
# Epoch 818/1000 - Accuracy: 0.9700
# Epoch 819/1000 - Accuracy: 0.9500
# Epoch 820/1000 - Accuracy: 0.9600
# Epoch 821/1000 - Accuracy: 0.9500
# Epoch 822/1000 - Accuracy: 0.9800
# Epoch 823/1000 - Accuracy: 0.9700
# Epoch 824/1000 - Accuracy: 0.9500
# Epoch 825/1000 - Accuracy: 0.9800
# Epoch 826/1000 - Accuracy: 0.9800
# Epoch 827/1000 - Accuracy: 0.9700
# Epoch 828/1000 - Accuracy: 0.9500
# Epoch 829/1000 - Accuracy: 0.9500
# Epoch 830/1000 - Accuracy: 0.9800
# Epoch 831/1000 - Accuracy: 0.9700
# Epoch 832/1000 - Accuracy: 0.9500
# Epoch 833/1000 - Accuracy: 0.9800
# Epoch 834/1000 - Accuracy: 0.9800
# Epoch 835/1000 - Accuracy: 0.9700
# Epoch 836/1000 - Accuracy: 0.9500
# Epoch 837/1000 - Accuracy: 0.9500
# Epoch 838/1000 - Accuracy: 0.9800
# Epoch 839/1000 - Accuracy: 0.9700
# Epoch 840/1000 - Accuracy: 0.9500
# Epoch 841/1000 - Accuracy: 0.9800
# Epoch 842/1000 - Accuracy: 0.9700
# Epoch 843/1000 - Accuracy: 0.9500
# Epoch 844/1000 - Accuracy: 0.9600
# Epoch 845/1000 - Accuracy: 0.9500
# Epoch 846/1000 - Accuracy: 0.9800
# Epoch 847/1000 - Accuracy: 0.9700
# Epoch 848/1000 - Accuracy: 0.9500
# Epoch 849/1000 - Accuracy: 0.9600
# Epoch 850/1000 - Accuracy: 0.9500
# Epoch 851/1000 - Accuracy: 0.9800
# Epoch 852/1000 - Accuracy: 0.9700
# Epoch 853/1000 - Accuracy: 0.9500
# Epoch 854/1000 - Accuracy: 0.9600
# Epoch 855/1000 - Accuracy: 0.9500
# Epoch 856/1000 - Accuracy: 0.9800
# Epoch 857/1000 - Accuracy: 0.9700
# Epoch 858/1000 - Accuracy: 0.9500
# Epoch 859/1000 - Accuracy: 0.9800
# Epoch 860/1000 - Accuracy: 0.9700
# Epoch 861/1000 - Accuracy: 0.9600
# Epoch 862/1000 - Accuracy: 0.9600
# Epoch 863/1000 - Accuracy: 0.9500
# Epoch 864/1000 - Accuracy: 0.9600
# Epoch 865/1000 - Accuracy: 0.9500
# Epoch 866/1000 - Accuracy: 0.9600
# Epoch 867/1000 - Accuracy: 0.9500
# Epoch 868/1000 - Accuracy: 0.9700
# Epoch 869/1000 - Accuracy: 0.9600
# Epoch 870/1000 - Accuracy: 0.9600
# Epoch 871/1000 - Accuracy: 0.9500
# Epoch 872/1000 - Accuracy: 0.9600
# Epoch 873/1000 - Accuracy: 0.9500
# Epoch 874/1000 - Accuracy: 0.9600
# Epoch 875/1000 - Accuracy: 0.9500
# Epoch 876/1000 - Accuracy: 0.9700
# Epoch 877/1000 - Accuracy: 0.9500
# Epoch 878/1000 - Accuracy: 0.9500
# Epoch 879/1000 - Accuracy: 0.9500
# Epoch 880/1000 - Accuracy: 0.9600
# Epoch 881/1000 - Accuracy: 0.9500
# Epoch 882/1000 - Accuracy: 0.9600
# Epoch 883/1000 - Accuracy: 0.9500
# Epoch 884/1000 - Accuracy: 0.9600
# Epoch 885/1000 - Accuracy: 0.9500
# Epoch 886/1000 - Accuracy: 0.9700
# Epoch 887/1000 - Accuracy: 0.9600
# Epoch 888/1000 - Accuracy: 0.9600
# Epoch 889/1000 - Accuracy: 0.9500
# Epoch 890/1000 - Accuracy: 0.9600
# Epoch 891/1000 - Accuracy: 0.9500
# Epoch 892/1000 - Accuracy: 0.9600
# Epoch 893/1000 - Accuracy: 0.9500
# Epoch 894/1000 - Accuracy: 0.9700
# Epoch 895/1000 - Accuracy: 0.9500
# Epoch 896/1000 - Accuracy: 0.9500
# Epoch 897/1000 - Accuracy: 0.9500
# Epoch 898/1000 - Accuracy: 0.9500
# Epoch 899/1000 - Accuracy: 0.9700
# Epoch 900/1000 - Accuracy: 0.9600
# Epoch 901/1000 - Accuracy: 0.9600
# Epoch 902/1000 - Accuracy: 0.9500
# Epoch 903/1000 - Accuracy: 0.9500
# Epoch 904/1000 - Accuracy: 0.9500
# Epoch 905/1000 - Accuracy: 0.9500
# Epoch 906/1000 - Accuracy: 0.9500
# Epoch 907/1000 - Accuracy: 0.9700
# Epoch 908/1000 - Accuracy: 0.9600
# Epoch 909/1000 - Accuracy: 0.9600
# Epoch 910/1000 - Accuracy: 0.9500
# Epoch 911/1000 - Accuracy: 0.9600
# Epoch 912/1000 - Accuracy: 0.9500
# Epoch 913/1000 - Accuracy: 0.9500
# Epoch 914/1000 - Accuracy: 0.9500
# Epoch 915/1000 - Accuracy: 0.9500
# Epoch 916/1000 - Accuracy: 0.9500
# Epoch 917/1000 - Accuracy: 0.9700
# Epoch 918/1000 - Accuracy: 0.9600
# Epoch 919/1000 - Accuracy: 0.9600
# Epoch 920/1000 - Accuracy: 0.9600
# Epoch 921/1000 - Accuracy: 0.9500
# Epoch 922/1000 - Accuracy: 0.9500
# Epoch 923/1000 - Accuracy: 0.9500
# Epoch 924/1000 - Accuracy: 0.9500
# Epoch 925/1000 - Accuracy: 0.9600
# Epoch 926/1000 - Accuracy: 0.9600
# Epoch 927/1000 - Accuracy: 0.9600
# Epoch 928/1000 - Accuracy: 0.9600
# Epoch 929/1000 - Accuracy: 0.9500
# Epoch 930/1000 - Accuracy: 0.9700
# Epoch 931/1000 - Accuracy: 0.9600
# Epoch 932/1000 - Accuracy: 0.9600
# Epoch 933/1000 - Accuracy: 0.9700
# Epoch 934/1000 - Accuracy: 0.9500
# Epoch 935/1000 - Accuracy: 0.9600
# Epoch 936/1000 - Accuracy: 0.9600
# Epoch 937/1000 - Accuracy: 0.9600
# Epoch 938/1000 - Accuracy: 0.9600
# Epoch 939/1000 - Accuracy: 0.9500
# Epoch 940/1000 - Accuracy: 0.9600
# Epoch 941/1000 - Accuracy: 0.9500
# Epoch 942/1000 - Accuracy: 0.9700
# Epoch 943/1000 - Accuracy: 0.9600
# Epoch 944/1000 - Accuracy: 0.9600
# Epoch 945/1000 - Accuracy: 0.9700
# Epoch 946/1000 - Accuracy: 0.9500
# Epoch 947/1000 - Accuracy: 0.9600
# Epoch 948/1000 - Accuracy: 0.9600
# Epoch 949/1000 - Accuracy: 0.9600
# Epoch 950/1000 - Accuracy: 0.9600
# Epoch 951/1000 - Accuracy: 0.9700
# Epoch 952/1000 - Accuracy: 0.9500
# Epoch 953/1000 - Accuracy: 0.9600
# Epoch 954/1000 - Accuracy: 0.9600
# Epoch 955/1000 - Accuracy: 0.9600
# Epoch 956/1000 - Accuracy: 0.9500
# Epoch 957/1000 - Accuracy: 0.9700
# Epoch 958/1000 - Accuracy: 0.9600
# Epoch 959/1000 - Accuracy: 0.9600
# Epoch 960/1000 - Accuracy: 0.9700
# Epoch 961/1000 - Accuracy: 0.9700
# Epoch 962/1000 - Accuracy: 0.9600
# Epoch 963/1000 - Accuracy: 0.9600
# Epoch 964/1000 - Accuracy: 0.9700
# Epoch 965/1000 - Accuracy: 0.9500
# Epoch 966/1000 - Accuracy: 0.9600
# Epoch 967/1000 - Accuracy: 0.9600
# Epoch 968/1000 - Accuracy: 0.9600
# Epoch 969/1000 - Accuracy: 0.9700
# Epoch 970/1000 - Accuracy: 0.9600
# Epoch 971/1000 - Accuracy: 0.9600
# Epoch 972/1000 - Accuracy: 0.9600
# Epoch 973/1000 - Accuracy: 0.9700
# Epoch 974/1000 - Accuracy: 0.9500
# Epoch 975/1000 - Accuracy: 0.9600
# Epoch 976/1000 - Accuracy: 0.9600
# Epoch 977/1000 - Accuracy: 0.9600
# Epoch 978/1000 - Accuracy: 0.9600
# Epoch 979/1000 - Accuracy: 0.9500
# Epoch 980/1000 - Accuracy: 0.9500
# Epoch 981/1000 - Accuracy: 0.9500
# Epoch 982/1000 - Accuracy: 0.9500
# Epoch 983/1000 - Accuracy: 0.9600
# Epoch 984/1000 - Accuracy: 0.9600
# Epoch 985/1000 - Accuracy: 0.9600
# Epoch 986/1000 - Accuracy: 0.9600
# Epoch 987/1000 - Accuracy: 0.9700
# Epoch 988/1000 - Accuracy: 0.9500
# Epoch 989/1000 - Accuracy: 0.9500
# Epoch 990/1000 - Accuracy: 0.9500
# Epoch 991/1000 - Accuracy: 0.9500
# Epoch 992/1000 - Accuracy: 0.9700
# Epoch 993/1000 - Accuracy: 0.9500
# Epoch 994/1000 - Accuracy: 0.9500
# Epoch 995/1000 - Accuracy: 0.9500
# Epoch 996/1000 - Accuracy: 0.9500
# Epoch 997/1000 - Accuracy: 0.9600
# Epoch 998/1000 - Accuracy: 0.9600
# Epoch 999/1000 - Accuracy: 0.9600
# Epoch 1000/1000 - Accuracy: 0.9700

# %% [markdown]
# <h4 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# 🤔
# پرسش
# </font>
# </h4>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir">
#     از میان سه حالت مختلفی که برای کلاس‌های مجموعه‌داده در نظر گرفتیم، یک یا چند حالت به‌صورت خطی تفکیک‌پذیر هستند. تفکیک‌پذیر خطی بودن آن‌ها را می‌توان طبق دقت به‌دست‌آمده توسط مدل نتیجه‌گیری کرد. طبق نتایج به‌دست‌آمده در اجرای خود فکر می‌کنید کدام حالت یا حالت‌ها به‌صورت خطی تفکیک‌پذیر هستند؟ پاسخ را در متغیر <code>linearly_separable</code> به شکل یک لیست وارد کنید. به عنوان مثال اگر پاسخ شما حالت اول یعنی کلاس‌های <code>Iris-setosa</code> و <code>Iris-versicolor</code> است آنگاه <code>linearly_separable</code> را به‌صورت <code>[1]</code> و اگر پاسخ شما مثلاً حالت دوم و سوم است آن را به شکل <code dir=ltr>[2, 3]</code> مقداردهی کنید.
# </font>
# </p>

# %%
linearly_separable = [1, 2]

# %% [markdown]
# <h3 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# قاعده‌ی دلتا
# </font>
# </h3>
# <center>
# <img src="delta_rule.png">
# </center>
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#     در این حالت می‌خواهیم کلاسی با نام <code>Adaline</code> بسازیم و  مدل را با قاعده‌ی دلتا آموزش دهیم. در اینجا از روش نزول گرادیان استفاده خواهیم کرد، یعنی تمام نمونه‌های آموزشی به‌صورت همزمان بر روی آپدیت وزن تاثیر می‌گذارند (برخلاف روش نزول گرادیان تصادفی که هربار یک نمونه دیده می‌شد). کد این مدل بسیار شبیه به حالت قبلی خواهد بود و تنها نیاز است چند مورد جزئی زیر را اعمال کنید:
#     <br>
#     <ul dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
#         <li>
#         از آنجا که در این حالت از تابع فعال‌سازی خطی استفاده می‌شود تابع <code>activation</code> تنها همان ورودی وزن‌دار خود را بدون هیچ‌گونه تغییری خروجی می‌دهد.
#         </li>
#         <li>
#         در تابع <code>prediction</code> پس از وزن‌دار کردن و عبور از تابع فعال‌سازی، باید بررسی کنید که اگر حاصل بزرگتر یا مساوی صفر بود، مقدار پیش‌بینی <code dir=ltr>+1</code> و در غیر این‌صورت <code dir=ltr>-1</code> شود.
#         </li>
#         <li>
#         پیشنهاد می‌شود به جای اینکه یک حلقه بنویسید که خطای هر نمونه را محاسبه کند و در آخر از مجموع آن جهت آپدیت وزن استفاده کنید، همین کار را به‌صورت برداری انجام دهید (با ضرب نقطه‌ای ترانهاده‌ی ماتریس ورودی در بردار وزن).
#         </li>
#     </ul>
# </font>
# </p>

# %%
class Adaline:

    def __init__(self):
        self.weights = None

    def weighting(self, input):
        return np.dot(input, self.weights)

    def activation(self, weighted_input):
        return weighted_input

    def predict(self, inputs):
        predictions = []
        features_pred = np.c_[np.ones(inputs.shape[0]), inputs]
        for x in features_pred:
            weighted_input = self.weighting(x)
            activation_output = self.activation(weighted_input)
            prediction = 1 if activation_output >= 0 else -1
            predictions.append(prediction) 
        return np.array(predictions)

    def fit(self, inputs, outputs, learning_rate=0.01, epochs=64):
        features = np.c_[np.ones(inputs.shape[0]), inputs]
        self.weights = np.random.rand(features.shape[1])
        for e in range(epochs):
            weighted_inputs = self.weighting(features)
            activation_outputs = self.activation(weighted_inputs)
            errors = outputs - activation_outputs
            self.weights += learning_rate * np.dot(features.T, errors)
            accuracy = accuracy_score(outputs, self.predict(inputs))
            print(f"Epoch {e+1}/{epochs} - Accuracy: {accuracy:.4f}")
            if accuracy == 1.0:
                break

# %% [markdown]
# <h4 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# آموزش مدل
# </font>
# </h4>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir">
#     پس از طراحی ساختار پرسپترون می‌توانید به کمک <code dir=ltr>Adaline()</code> ابتدا یک نمونه از این کلاس بسازید و سپس تابع <code>fit</code> را با آرگومان‌های مناسب صدا بزنید تا آموزش مدل آغاز شود. این کار را برای هر سه حالت ورودی انجام دهید. پیشنهاد می‌شود مقادیر مختلف نرخ یادگیری مانند 0.1، 0.01، 0.001 و... را آزمایش و مقایسه کنید.
# </font>
# </p>

# %%
adaline = Adaline()
adaline.fit(df1,target_df1)
# Out:
# Epoch 1/64 - Accuracy: 0.5000
# Epoch 2/64 - Accuracy: 0.5000
# Epoch 3/64 - Accuracy: 0.6100
# Epoch 4/64 - Accuracy: 0.9500
# Epoch 5/64 - Accuracy: 0.9700
# Epoch 6/64 - Accuracy: 1.0000

# %%
adaline = Adaline()
adaline.fit(df2, target_df2)
# Out:
# Epoch 1/64 - Accuracy: 0.5000
# Epoch 2/64 - Accuracy: 0.5000
# Epoch 3/64 - Accuracy: 0.6100
# Epoch 4/64 - Accuracy: 1.0000

# %%
adaline = Adaline()
adaline.fit(df3, target_df3)
# Out:
# Epoch 1/64 - Accuracy: 0.5000
# Epoch 2/64 - Accuracy: 0.5000
# Epoch 3/64 - Accuracy: 0.5000
# Epoch 4/64 - Accuracy: 0.5000
# Epoch 5/64 - Accuracy: 0.5000
# Epoch 6/64 - Accuracy: 0.5000
# Epoch 7/64 - Accuracy: 0.5000
# Epoch 8/64 - Accuracy: 0.5400
# Epoch 9/64 - Accuracy: 0.5000
# Epoch 10/64 - Accuracy: 0.5600
# Epoch 11/64 - Accuracy: 0.5100
# Epoch 12/64 - Accuracy: 0.6000
# Epoch 13/64 - Accuracy: 0.5100
# Epoch 14/64 - Accuracy: 0.6400
# Epoch 15/64 - Accuracy: 0.5700
# Epoch 16/64 - Accuracy: 0.7100
# Epoch 17/64 - Accuracy: 0.6300
# Epoch 18/64 - Accuracy: 0.7300
# Epoch 19/64 - Accuracy: 0.6900
# Epoch 20/64 - Accuracy: 0.7700
# Epoch 21/64 - Accuracy: 0.7300
# Epoch 22/64 - Accuracy: 0.7700
# Epoch 23/64 - Accuracy: 0.7800
# Epoch 24/64 - Accuracy: 0.8300
# Epoch 25/64 - Accuracy: 0.7900
# Epoch 26/64 - Accuracy: 0.8500
# Epoch 27/64 - Accuracy: 0.8200
# Epoch 28/64 - Accuracy: 0.8800
# Epoch 29/64 - Accuracy: 0.8500
# Epoch 30/64 - Accuracy: 0.9000
# Epoch 31/64 - Accuracy: 0.8700
# Epoch 32/64 - Accuracy: 0.9200
# Epoch 33/64 - Accuracy: 0.8800
# Epoch 34/64 - Accuracy: 0.9400
# Epoch 35/64 - Accuracy: 0.8900
# Epoch 36/64 - Accuracy: 0.9500
# Epoch 37/64 - Accuracy: 0.9000
# Epoch 38/64 - Accuracy: 0.9500
# Epoch 39/64 - Accuracy: 0.9000
# Epoch 40/64 - Accuracy: 0.9500
# Epoch 41/64 - Accuracy: 0.9100
# Epoch 42/64 - Accuracy: 0.9500
# Epoch 43/64 - Accuracy: 0.9100
# Epoch 44/64 - Accuracy: 0.9500
# Epoch 45/64 - Accuracy: 0.9200
# Epoch 46/64 - Accuracy: 0.9500
# Epoch 47/64 - Accuracy: 0.9200
# Epoch 48/64 - Accuracy: 0.9500
# Epoch 49/64 - Accuracy: 0.9300
# Epoch 50/64 - Accuracy: 0.9400
# Epoch 51/64 - Accuracy: 0.9300
# Epoch 52/64 - Accuracy: 0.9400
# Epoch 53/64 - Accuracy: 0.9400
# Epoch 54/64 - Accuracy: 0.9400
# Epoch 55/64 - Accuracy: 0.9700
# Epoch 56/64 - Accuracy: 0.9500
# Epoch 57/64 - Accuracy: 0.9700
# Epoch 58/64 - Accuracy: 0.9500
# Epoch 59/64 - Accuracy: 0.9700
# Epoch 60/64 - Accuracy: 0.9500
# Epoch 61/64 - Accuracy: 0.9800
# Epoch 62/64 - Accuracy: 0.9600
# Epoch 63/64 - Accuracy: 0.9800
# Epoch 64/64 - Accuracy: 0.9600

# %% [markdown]
# <h4 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# 💭
# تفکر
# </font>
# </h4>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir">
#     مقایسه‌ی عملکرد دو مدل <code>Perceptron</code> و <code>Adaline</code> در حالتی که مجموعه‌داده به شکل خطی تفکیک‌پذیر نباشد می‌تواند به شکل عملی تفاوت میان این دو مدل را برای‌تان شفاف سازد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>داوری</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
# در این تمرین هرکدام از توابعی که پیاده کرده‌اید به‌صورت جداگانه مورد داوری قرار خواهد گرفت تا از عملکرد هرکدام به شکل جداگانه مطمئن شوید. البته تابع <code>fit</code> هر کلاس به منزله‌ی عملکرد کلی مدل است و جهت ارزیابی، مدل شما بر روی یک حالت تفکیک‌پذیر خطی از مجموعه‌داده iris آموزش خواهد دید و انتظار می‌رود که بتواند دقت تقریبی ۱۰۰ درصد را بر روی مجموعه‌ی آموزشی به دست آورد. علاوه بر این دیتافریم‌های اولیه و پاسخ شما به پرسش مطرح‌شده درباره‌ی تفکیک‌پذیری خطی نیز امتیازدهی خواهد شد.
# </font>
# </p>

# %% [markdown]
# <h2 align=right style="line-height:200%;font-family:vazir;color:#0099cc">
# <font face="vazir" color="#0099cc">
# <b>سلول جواب‌ساز</b>
# </font>
# </h2>
#
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     سلول‌های زیر را به منظور ساخت فایل‌های کلاس‌های پیاده‌سازی شده و پاسخ خود به پرسش مطرح شده اجرا نمایید.
# </font>
# </p>

# %%
with open("linearly_separable.json", "w") as f:
    json.dump(linearly_separable, f)
f.close()

# %%
inspect_perceptron = Perceptron()
with open("Perceptron.py", "w") as f:
    f.write('import numpy as np\n')
    f.write('from sklearn.metrics import accuracy_score\n')
    f.write('class Perceptron:\n')
    f.write(getsource(inspect_perceptron.__init__)+'\n')
    f.write(getsource(inspect_perceptron.weighting)+'\n')
    f.write(getsource(inspect_perceptron.activation)+'\n')
    f.write(getsource(inspect_perceptron.predict)+'\n')
    f.write(getsource(inspect_perceptron.fit)+'\n')
f.close()

# %%
inspect_adaline = Adaline()
with open("Adaline.py", "w") as f:
    f.write('import numpy as np\n')
    f.write('from sklearn.metrics import accuracy_score\n')
    f.write('class Adaline:\n')
    f.write(getsource(inspect_adaline.__init__)+'\n')
    f.write(getsource(inspect_adaline.weighting)+'\n')
    f.write(getsource(inspect_adaline.activation)+'\n')
    f.write(getsource(inspect_adaline.predict)+'\n')
    f.write(getsource(inspect_adaline.fit)+'\n')
f.close()

# %% [markdown]
# <p dir=rtl style="direction: rtl; text-align: justify; line-height:200%; font-family:vazir; font-size:medium">
# <font face="vazir" size=3>
#     برای ساخته‌شدن فایل <code>result.zip</code> سلول زیر را اجرا کنید. توجه داشته باشید که پیش از اجرای سلول زیر تغییرات اعمال شده در نت‌بوک را ذخیره کرده باشید (<code>ctrl+s</code>) تا در صورت نیاز به پشتیبانی امکان بررسی کد شما وجود داشته باشد.
# </font>
# </p>

# %%
import zipfile
import joblib

def compress(file_names):
    print("File Paths:")
    print(file_names)
    compression = zipfile.ZIP_DEFLATED
    with zipfile.ZipFile("result.zip", mode="w") as zf:
        for file_name in file_names:
            zf.write('./' + file_name, file_name, compress_type=compression)

file_names = ['df1.csv', 'df2.csv', 'df3.csv', 'perceptron.ipynb', 'Perceptron.py', 'Adaline.py', 'linearly_separable.json']
compress(file_names)
# Out:
# File Paths:
# ['df1.csv', 'df2.csv', 'df3.csv', 'perceptron.ipynb', 'Perceptron.py', 'Adaline.py', 'linearly_separable.json']
